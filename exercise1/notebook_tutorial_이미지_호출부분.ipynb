# %%
import PIL.Image

# %%
pip install --upgrade Pillow
# Out:
# Requirement already up-to-date: Pillow in /Applications/anaconda3/lib/python3.7/site-packages (7.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
PIL.Image.open('images/notebook_tutorial/cat_example.jpg')
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=325x340 at 0x10972EF50>
